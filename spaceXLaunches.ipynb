# %% [markdown]
# <a href="https://colab.research.google.com/github/Williamsjanthony15/spaceX_launch/blob/main/spaceXLaunches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Dependencies

# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression

# %% [markdown]
# Import CSV File

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-b7b21f1d-6870-4c8c-960d-acd12b469e95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7b21f1d-6870-4c8c-960d-acd12b469e95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving database.csv to database (2).csv

# %% [markdown]
# Assigning DF to the CSV File

# %%
df = pd.read_csv('./database.csv')
df
# Out:
#    Flight Number        Launch Date  ... Landing Type Landing Outcome
# 0           F1-1      24 March 2006  ...          NaN             NaN
# 1           F1-2      21 March 2007  ...          NaN             NaN
# 2           F1-3      3 August 2008  ...          NaN             NaN
# 3           F1-3      3 August 2008  ...          NaN             NaN
# 4           F1-3      3 August 2008  ...          NaN             NaN
# 5           F1-4  28 September 2008  ...          NaN             NaN
# 6           F1-5       14 July 2009  ...          NaN             NaN
# 7           F9-1        4 June 2010  ...    Parachute         Failure
# 8           F9-2    8 December 2010  ...    Parachute         Failure
# 9           F9-3        22 May 2012  ...          NaN             NaN
# 10          F9-4     8 October 2012  ...          NaN             NaN
# 11          F9-4     8 October 2012  ...          NaN             NaN
# ...

# %% [markdown]
# Show first 5 rows of DF

# %%
df.head(5)

# %% [markdown]
# Show the description and the info of the data set.

# %%
df.columns

# %%
df.info

# %% [markdown]
# Ensure that any date columns have been cast into a datetime object in your DataFrame.

# %%
df = df.drop(index=0)
df['Launch Date'] = pd.to_datetime(df['Launch Date']).sort_values(ascending=False).head(40)
date = df[['Launch Date', 'Launch Time']]

date
# Out:
#    Launch Date Launch Time
# 1   2007-03-21       01:10
# 2   2008-08-03       03:34
# 3   2008-08-03       03:34
# 4   2008-08-03       03:34
# 5   2008-09-28       23:15
# 6   2009-07-14       03:35
# 7   2010-06-04       18:45
# 8   2010-12-08       15:43
# 9   2012-05-22       07:44
# 10  2012-10-08       00:35
# 11  2012-10-08       00:35
# 12  2013-03-01       15:10
# 13  2013-09-29       16:00
# 14  2013-12-03       22:41
# 15  2014-12-06       22:06
# 16  2014-04-18       19:25
# 17  2014-07-14       15:15
# 18  2014-08-05       08:00
# 19  2014-09-07       05:00
# 20  2014-09-21       05:52
# 21  2015-01-10       09:47
# 22  2015-02-11       23:03
# 23  2015-03-02       03:50
# 24  2015-03-02       03:50
# 25  2015-04-14       20:10
# 26  2015-04-27       23:03
# 27  2015-06-28       14:21
# 28  2015-12-22       01:29
# 29  2016-01-17       18:42
# 30  2016-03-04       23:35
# 31  2016-04-08       20:43
# 32  2016-05-06       05:21
# 33  2016-05-27       21:39
# ...

# %%
time = pd.to_datetime(df['Launch Time'].sort_values(ascending=False)).head(50)
time

# %% [markdown]
# Using a regression model, split your data into train and test data

# %%
stringified = {'Success': True, 'Failure': False}
new_results = df['Mission Outcome'].map(stringified)
new_results

# %%
# exception = str.replace('NaN', 'None', '-1')
X = df['Mission Outcome'].map(stringified).values
# y = df['Payload Type'].replace(NaN, 'None').values
y = df['Payload Type'].fillna('None').values

# lr = LogisticRegression
# lr.fit(X, y)
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)
# NaN_exception = df['Payload Type'].apply(lambda y: ('NaN','Unknown'))
y
# Out:
# array([['Research Satellite'],
#        ['None'],
#        ['Communication Satellite'],
#        ['Research Satellites'],
#        ['Human Remains'],
#        ['None'],
#        ['Weather Satellite'],
#        ['None'],
#        ['Space Station Supplies'],
#        ['Space Station Supplies'],
#        ['Space Station Supplies'],
#        ['Communication Satellite'],
#        ['Space Station Supplies'],
#        ['Communication/Research Satellite'],
#        ['Communication Satellite'],
#        ['Communication Satellite'],
#        ['Space Station Supplies'],
#        ['Communication Satellite'],
#        ['Communication Satellite'],
#        ['Communication Satellite'],
#        ['Space Station Supplies'],
#        ['Space Station Supplies'],
#        ['Weather Satellite'],
#        ['Communication Satellite'],
#        ['Communication Satellite'],
#        ['Space Station Supplies'],
#        ['Communication Satellite'],
#        ['Space Station Supplies'],
# ...

# %%
model = LinearRegression()
model.fit(X, y)

# %% [markdown]
# Fit your training split to the regression model.

# %% [markdown]
# Show your regression model’s score.

# %% [markdown]
# Draw at least three conclusions from your regression model.

# %%
print('SpaceX is not only Utilizing Government and personal funded aircraft to ship into space, but they are utilizing other countries, Which allow other countries to send into space as well')
print('More Failures than success\' Shows us that some times you need to fail before you can succeed')
print('Even those in the highest intellectual positions, can fail.')
